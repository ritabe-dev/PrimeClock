# %% [markdown]
# # Branch Decomposition
#
# Inspect branches `k = floor(N/p)`.

# %%
from prime_reciprocal_projection import branch_decomposition

branches = branch_decomposition(100000, max_k=20)
[(branch.k, branch.count, round(branch.mass, 4), round(branch.limit_mass, 4)) for branch in branches[:10]]
