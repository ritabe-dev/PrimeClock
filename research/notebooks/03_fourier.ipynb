# %% [markdown]
# # Fourier Diagnostics
#
# Compute empirical Fourier coefficients for low modes.

# %%
from prime_reciprocal_projection import fourier_coefficient

N = 10000
[(m, fourier_coefficient(N, m)) for m in range(5)]
