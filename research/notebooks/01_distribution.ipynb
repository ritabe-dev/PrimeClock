# %% [markdown]
# # Distribution
#
# Compare empirical PRP bin masses with the limiting density bin masses.

# %%
from prime_reciprocal_projection.projection import fractional_parts
from prime_reciprocal_projection.experiments import histogram_masses, limit_bin_masses

N = 100000
edges, empirical = histogram_masses(fractional_parts(N), bins=100)
_, limit = limit_bin_masses(bins=100)
sum(empirical), sum(limit)
